# %% [markdown]
# <a href="https://colab.research.google.com/github/MFSyafiq/ML_ARIMA_Cluster/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade statsmodels

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer, MinMaxScaler

from sklearn.metrics import mean_absolute_error, mean_squared_error, silhouette_score

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt
from statsmodels.tsa.arima.model import ARIMA
from pandas.plotting import autocorrelation_plot

import warnings
warnings.filterwarnings('ignore')

# %%
# set plot style for whole notebook
sns.set_style('darkgrid')

# %%
df_cs = pd.read_csv(r'/content/Customer.csv', delimiter=';')
df_pr = pd.read_csv(r'/content/Product.csv', delimiter=';')
df_str = pd.read_csv(r'/content/Store.csv', delimiter=';')
df_tr = pd.read_csv(r'/content/transaction.csv', delimiter=';')

# %%
df_cs.shape, df_pr.shape, df_str.shape, df_tr.shape
# Out:
# ((447, 5), (10, 3), (14, 6), (5020, 8))

# %% [markdown]
# # DATA CLEANSING

# %%
df_cs.head()
# Out:
#    CustomerID  Age  Gender Marital Status Income
# 0           1   55       1        Married   5,12
# 1           2   60       1        Married   6,23
# 2           3   32       1        Married   9,17
# 3           4   31       1        Married   4,87
# 4           5   58       1        Married   3,57

# %%
df_cs.duplicated().sum()
# Out:
# 0

# %%
df_cs.isnull().sum()
# Out:
# CustomerID        0
# Age               0
# Gender            0
# Marital Status    3
# Income            0
# dtype: int64

# %%
df_pr.head()
# Out:
#   ProductID   Product Name  Price
# 0        P1      Choco Bar   8800
# 1        P2  Ginger Candy    3200
# 2        P3       Crackers   7500
# 3        P4    Potato Chip  12000
# 4        P5       Thai Tea   4200

# %%
df_pr.duplicated().sum()
# Out:
# 0

# %%
df_pr.isnull().sum()
# Out:
# ProductID       0
# Product Name    0
# Price           0
# dtype: int64

# %%
df_str.head()
# Out:
#    StoreID         StoreName GroupStore           Type   Latitude   Longitude
# 0        1     Prima Tendean      Prima   Modern Trade       -6,2  106,816666
# 1        2  Prima Kelapa Dua      Prima   Modern Trade  -6,914864  107,608238
# 2        3        Prima Kota      Prima   Modern Trade  -7,797068  110,370529
# 3        4       Gita Ginara       Gita  General Trade  -6,966667  110,416664
# 4        5           Bonafid       Gita  General Trade  -7,250445  112,768845

# %%
df_str.duplicated().sum()
# Out:
# 0

# %%
df_str.isnull().sum()
# Out:
# StoreID       0
# StoreName     0
# GroupStore    0
# Type          0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
df_tr.head()
# Out:
#   TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 0       TR11369         328  01/01/2022        P3   7500    4        30000
# 1       TR16356         165  01/01/2022        P9  10000    7        70000
# 2        TR1984         183  01/01/2022        P1   8800    4        35200
# 3       TR35256         160  01/01/2022        P1   8800    7        61600
# 4       TR41231         386  01/01/2022        P9  10000    1        10000
#
#    StoreID
# 0       12
# 1        1
# 2        4
# 3        4
# 4        4

# %%
df_str.duplicated().sum()
# Out:
# 0

# %%
df_tr.isnull().sum()
# Out:
# TransactionID    0
# CustomerID       0
# Date             0
# ProductID        0
# Price            0
# Qty              0
# TotalAmount      0
# StoreID          0
# dtype: int64

# %%
#data cleansing df_cs
df_cs['Income'] = df_cs['Income'].replace (',','.',regex=True).astype('float')

# %%
#data cleansing df_str
df_str['Latitude'] = df_str['Latitude'].replace (',','.',regex=True).astype('float')
df_str['Longitude'] = df_str['Longitude'].replace (',','.',regex=True).astype('float')

# %%
#data cleansing df_tr
df_tr['date'] = pd.to_datetime(df_tr['Date'])

# %%
# untuk transaksi yang lebih dari 1
df_tr['TransactionID'].value_counts()
# Out:
# TR71313    3
# TR42197    2
# TR90402    2
# TR74019    2
# TR49649    2
#           ..
# TR29792    1
# TR23081    1
# TR1691     1
# TR98388    1
# TR85684    1
# Name: TransactionID, Length: 4908, dtype: int64

# %%
df_tr[ df_tr['TransactionID'] == 'TR71313'] # ambil yang paling terbaru
# Out:
#      TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 1982       TR71313         117  21/05/2022        P1   8800   10        88000
# 3336       TR71313         401  30/08/2022        P3   7500    6        45000
# 3722       TR71313         370  26/09/2022        P3   7500    2        15000
#
#       StoreID       date
# 1982        8 2022-05-21
# 3336       11 2022-08-30
# 3722        3 2022-09-26

# %%
df_tr_sorted = df_tr.sort_values(by='date', ascending=False)
df_tr_sorted.head()
# Out:
#      TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 5019       TR85684          55  31/12/2022        P8  16000    1        16000
# 5013       TR38129         253  31/12/2022        P3   7500    5        37500
# 5008       TR12821         203  31/12/2022        P3   7500    1         7500
# 5009       TR13635         408  31/12/2022        P7   9400    4        37600
# 5010        TR1380         266  31/12/2022        P9  10000    3        30000
#
#       StoreID       date
# 5019        6 2022-12-31
# 5013        4 2022-12-31
# 5008       10 2022-12-31
# 5009        3 2022-12-31
# 5010       11 2022-12-31

# %%
df_tr_sorted_no_duplicate = df_tr_sorted.drop_duplicates(subset=['TransactionID'], keep='first')
df_tr_sorted_no_duplicate['TransactionID'].value_counts()
# Out:
# TR85684    1
# TR668      1
# TR56847    1
# TR61579    1
# TR78116    1
#           ..
# TR94959    1
# TR48538    1
# TR48377    1
# TR48509    1
# TR11369    1
# Name: TransactionID, Length: 4908, dtype: int64

# %%
df_tr_sorted_no_duplicate[ df_tr_sorted_no_duplicate['TransactionID'] == 'TR71313']
# Out:
#      TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 3722       TR71313         370  26/09/2022        P3   7500    2        15000
#
#       StoreID       date
# 3722        3 2022-09-26

# %% [markdown]
# # Merge All Data

# %%
df_merge = pd.merge(df_tr_sorted_no_duplicate, df_cs, on=['CustomerID'])
df_merge = pd.merge(df_merge, df_pr.drop(columns=['Price']), on=['ProductID'])
df_merge = pd.merge (df_merge, df_str, on=['StoreID'])

# %%
df_merge.head()
# Out:
#   TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 0       TR85684          55  31/12/2022        P8  16000    1        16000
# 1       TR29093         232  09/07/2022        P8  16000    3        48000
# 2       TR48254         195  28/08/2022        P8  16000    1        16000
# 3       TR23475         128  11/11/2022        P8  16000    3        48000
# 4       TR33420         296  06/06/2022        P8  16000    3        48000
#
#    StoreID       date  Age  Gender Marital Status  Income Product Name  \
# 0        6 2022-12-31   34       1        Married    8.44          Oat
# 1        6 2022-09-07   62       0        Married    7.32          Oat
# 2        6 2022-08-28   31       1        Married   10.91          Oat
# 3        6 2022-11-11    0       1        Married    6.77          Oat
# 4        6 2022-06-06   38       1         Single    3.18          Oat
#
#   StoreName GroupStore          Type  Latitude  Longitude
# ...

# %% [markdown]
# # Model Machine Learning Regresi (time series) Using ARIMA

# %%
df_regresi = df_merge.groupby(['date']).agg({
    'Qty':'sum'
}).reset_index()

# %%
df_regresi.head()
# Out:
#         date  Qty
# 0 2022-01-01   47
# 1 2022-01-02   45
# 2 2022-01-03   67
# 3 2022-01-04   98
# 4 2022-01-05   57

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

df_regresi['date'] = pd.to_datetime(df_regresi['date'])
df_regresi.set_index('date', inplace=True)
decomposed = seasonal_decompose(df_regresi)

plt.figure(figsize=(8, 8))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')

plt.tight_layout()

# %% [markdown]
# ## Check Stationarity Data

# %%
import statsmodels.api as sm

# Assuming your time series data is in a column named 'value'
ts = df_regresi['Qty']

# Perform the Augmented Dickey-Fuller test
result = sm.tsa.adfuller(ts)

# Extract the test statistic and p-value
adf_statistic, p_value, _, _, _, _ = result

# Print the results
print(f'ADF Statistic: {adf_statistic}')
print(f'p-value: {p_value}')

# Check if the time series is stationary based on the p-value
if p_value <= 0.05:  # You can adjust the significance level as needed
    print('The time series is stationary (reject the null hypothesis)')
else:
    print('The time series is non-stationary (fail to reject the null hypothesis)')

# Plot the time series for visual inspection
plt.plot(ts)
plt.title('Time Series Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
# Out:
# ADF Statistic: -19.323189851289346
# p-value: 0.0
# The time series is stationary (reject the null hypothesis)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

plot_acf(df_regresi, lags=40)
plot_pacf(df_regresi, lags=40)
plt.show()

# %%
plot_acf(df_regresi.Qty.diff().dropna())

# %%
plot_pacf(df_regresi.Qty.diff().dropna())

# %%
cut_off = round(df_regresi.shape[0]*0.8)
df_train = df_regresi[:cut_off].reset_index()
df_test = df_regresi[cut_off:].reset_index()
df_train.shape, df_test.shape
# Out:
# ((292, 2), (73, 2))

# %%
df_train
# Out:
#           date  Qty
# 0   2022-01-01   47
# 1   2022-01-02   45
# 2   2022-01-03   67
# 3   2022-01-04   98
# 4   2022-01-05   57
# ..         ...  ...
# 287 2022-10-15   33
# 288 2022-10-16   26
# 289 2022-10-17   53
# 290 2022-10-18   47
# 291 2022-10-19   34
#
# [292 rows x 2 columns]

# %%
df_test
# Out:
#          date  Qty
# 0  2022-10-20   39
# 1  2022-10-21   35
# 2  2022-10-22   56
# 3  2022-10-23   59
# 4  2022-10-24   39
# ..        ...  ...
# 68 2022-12-27   70
# 69 2022-12-28   68
# 70 2022-12-29   42
# 71 2022-12-30   44
# 72 2022-12-31   37
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data=df_train, x=df_train['date'], y=df_train['Qty']);
sns.lineplot(data=df_test, x=df_test['date'], y=df_test['Qty']);

# %%
autocorrelation_plot(df_regresi['Qty']);

# %% [markdown]
# ## Modelling

# %%
def rmse(y_actual, y_pred):
    '''
    Fungsi untuk menghitung RMSE
    '''
    rmse_value = np.sqrt(mean_squared_error(y_actual, y_pred))
    return rmse_value

def eval(y_actual, y_pred):
    '''
    Fungsi untuk mengevaluasi model machine learning
    '''
    rmse_value = rmse(y_actual, y_pred)
    mae_value = mean_absolute_error(y_actual, y_pred)

    print(f'RMSE value: {rmse_value}')
    print(f'MAE value: {mae_value}')

# %%
#ARIMA
df_train = df_train.set_index('date')
df_test = df_test.set_index('date')

y = df_train['Qty']

ARIMAmodel = ARIMA(y, order = (1, 0, 1))
ARIMAmodel = ARIMAmodel.fit()

y_pred = ARIMAmodel.get_forecast(len(df_test))

y_pred_df = y_pred.conf_int()
y_pred_df['predictions'] = ARIMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = df_test.index
y_pred_out = y_pred_df['predictions']
eval(df_test['Qty'], y_pred_out)

plt.figure(figsize=(20,5))
plt.plot(df_train['Qty'])
plt.plot(df_test['Qty'], color='red')
plt.plot(y_pred_out, color='black', label='ARIMA Predictions')
plt.legend()
# Out:
# RMSE value: 15.303311549579208
# MAE value: 12.619557206677145

# %%
import statsmodels.api as sm
model1 = ARIMA(y, order = (1, 0, 1))
model1_fit = model1.fit()
model1_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                    Qty   No. Observations:                  292
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1235.562
# Date:                Sun, 03 Sep 2023   AIC                           2479.123
# Time:                        10:40:34   BIC                           2493.830
# Sample:                    01-01-2022   HQIC                          2485.014
#                          - 10-19-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.1669      1.040     47.290      0.000      47.129      51.205
# ar.L1         -0.8431      0.408     -2.066      0.039      -1.643      -0.043
# ma.L1          0.8161      0.439      1.858      0.063      -0.045       1.677
# ...

# %% [markdown]
# # Clustering

# %%
 df_merge.head()
# Out:
#   TransactionID  CustomerID        Date ProductID  Price  Qty  TotalAmount  \
# 0       TR85684          55  31/12/2022        P8  16000    1        16000
# 1       TR29093         232  09/07/2022        P8  16000    3        48000
# 2       TR48254         195  28/08/2022        P8  16000    1        16000
# 3       TR23475         128  11/11/2022        P8  16000    3        48000
# 4       TR33420         296  06/06/2022        P8  16000    3        48000
#
#    StoreID       date  Age  Gender Marital Status  Income Product Name  \
# 0        6 2022-12-31   34       1        Married    8.44          Oat
# 1        6 2022-09-07   62       0        Married    7.32          Oat
# 2        6 2022-08-28   31       1        Married   10.91          Oat
# 3        6 2022-11-11    0       1        Married    6.77          Oat
# 4        6 2022-06-06   38       1         Single    3.18          Oat
#
#   StoreName GroupStore          Type  Latitude  Longitude
# ...

# %%
# identifikasi dulu kolom-kolom yang redundant/korelasi tinggi
df_merge.corr()
# Out:
#              CustomerID     Price       Qty  TotalAmount   StoreID       Age  \
# CustomerID     1.000000 -0.018455 -0.010682    -0.026893  0.006960 -0.027366
# Price         -0.018455  1.000000 -0.352883     0.440685 -0.032268  0.015108
# Qty           -0.010682 -0.352883  1.000000     0.621938  0.014229 -0.027469
# TotalAmount   -0.026893  0.440685  0.621938     1.000000 -0.011713 -0.015848
# StoreID        0.006960 -0.032268  0.014229    -0.011713  1.000000 -0.006817
# Age           -0.027366  0.015108 -0.027469    -0.015848 -0.006817  1.000000
# Gender        -0.011952  0.009841 -0.009329    -0.008609 -0.002742 -0.033418
# Income         0.005140  0.002551 -0.032932    -0.027744  0.004107  0.486784
# Latitude       0.003316 -0.028239 -0.005029    -0.030530  0.470375  0.007012
# Longitude     -0.005457  0.019527  0.004345     0.025761 -0.095237  0.021211
#
#                Gender    Income  Latitude  Longitude
# CustomerID  -0.011952  0.005140  0.003316  -0.005457
# ...

# %%
df_cluster = df_merge.groupby(['CustomerID']).agg({
    'TransactionID' : 'count',
    'Qty':'sum'
}).reset_index()

# %%
df_cluster.head()
# Out:
#    CustomerID  TransactionID  Qty
# 0           1             17   60
# 1           2             12   56
# 2           3             15   56
# 3           4             10   46
# 4           5              7   27

# %%
data_cluster = df_cluster.drop(columns=['CustomerID'])

data_cluster_normalize = preprocessing.normalize(data_cluster)

# %%
data_cluster_normalize
# Out:
# array([[0.27260257, 0.96212673],
#        [0.20952909, 0.97780241],
#        [0.25873609, 0.96594805],
#        [0.21242964, 0.97717636],
#        [0.25096216, 0.9679969 ],
#        [0.23635158, 0.9716676 ],
#        [0.27932954, 0.9601953 ],
#        [0.28334614, 0.95901771],
#        [0.2216211 , 0.97513286],
#        [0.26962993, 0.96296402],
#        [0.24253563, 0.9701425 ],
#        [0.25371269, 0.96727962],
#        [0.27074558, 0.96265094],
#        [0.32432432, 0.94594595],
#        [0.26311741, 0.96476382],
#        [0.25163385, 0.96782251],
#        [0.25912857, 0.96584284],
#        [0.30320366, 0.95292578],
#        [0.23162053, 0.97280621],
#        [0.27472113, 0.96152395],
#        [0.27472113, 0.96152395],
#        [0.29221854, 0.95635157],
#        [0.26311741, 0.96476382],
#        [0.28497027, 0.95853636],
#        [0.28734789, 0.95782629],
#        [0.30782029, 0.95144452],
#        [0.29827499, 0.95447998],
#        [0.28216632, 0.9593655 ],
# ...

# %%
K = range (2, 8)
fits = []
score = []

for k in K:
  model = KMeans(n_clusters = k, random_state=0, n_init='auto').fit(data_cluster_normalize)

  fits.append(model)

  score.append(silhouette_score(data_cluster_normalize, model.labels_, metric='euclidean'))

# %%
# choose 4 cluster
sns.lineplot(x=K, y=score);

# %%
fits[1]
# Out:
# KMeans(n_clusters=3, n_init='auto', random_state=0)

# %%
df_cluster['cluster_label'] = fits[1].labels_

# %%
df_cluster.groupby(['cluster_label']).agg({
    'CustomerID' : 'count',
    'TransactionID' : 'mean',
    'Qty' : 'sum'
})
# Out:
#                CustomerID  TransactionID   Qty
# cluster_label
# 0                     185      10.540541  8157
# 1                      67      10.761194  2012
# 2                     195      11.471795  7688

# %% [markdown]
# cluster 0 itu paling tinggi total amount nya tapi qty nya nomor 3 -- > kasih promo
